# %% [markdown]
# # Cours5 - Optimisation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# notre "Solveur Excel"
import scipy.optimize

# %%
df = pd.read_excel("problemes\\lot_économique.xlsx")

# %%
df.head()
# Out:
#    taille t  nombre de commandes / an  stock moyen  coût annuel de stockage  \
# 0         1                    1500.0          0.5                       10
# 1         2                     750.0          1.0                       20
# 2         3                     500.0          1.5                       30
# 3         4                     375.0          2.0                       40
# 4         5                     300.0          2.5                       50
#
#    coût annuel de commande  coût annuel total
# 0                 225000.0           225010.0
# 1                 112500.0           112520.0
# 2                  75000.0            75030.0
# 3                  56250.0            56290.0
# 4                  45000.0            45050.0

# %% [markdown]
# excel check
#
# ![excel](cout_annu.png)

# %%
# taille du graph
plt.rcParams["figure.figsize"] = (16,9)

# ajout des elements (lignes et point)
plt.plot(df['coût annuel de stockage'], label='coût annuel stockage')
plt.plot(df['coût annuel de commande'], label='coût annuel commande')
plt.plot(df['coût annuel total'], 'k', label='coût annuel total')
plt.plot(150,3000, "or", label='minimum')

# les ecritures
plt.title("Couts annuels en fonction de la taille de commande")
plt.ylabel("Cout annuel (en $)")
plt.xlabel("Taille t de la commande (nb. de caisses)")

# ajustement d la limite de Y pour etre comme le graph excel
plt.ylim(0,25000)

# ajustements graphiques
plt.legend()
plt.grid(True)

# Go!
plt.show()

# %% [markdown]
# Dans le solveur Excel, GRG stands for “Generalized Reduced Gradient”.
#
# "According to Frontline Systems, the developer of the Solver add-in for Excel, their GRG non-linear solver is based on work published by Leon Lasdon in 1973 and Alan Waren and their 1975 published code implementation. The latter link is for an Office of Naval Research publication, so you can download the entire text for free."
#
# Je ne trouve pas d'equivalent dans SciPY.
#
# Je vais utiliser celui-ci puisqu'il est classifier comme general et non-lineaire:
#
# ```
# scipy.optimize.broyden1(F, xin, iter=None, alpha=None, reduction_method='restart', max_rank=None, verbose=False, maxiter=None, f_tol=None, f_rtol=None, x_tol=None, x_rtol=None, tol_norm=None, line_search='armijo', callback=None, **kw)[source]
# ```
